# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvs0712-maker/Machine-Learning-codes/blob/main/creating%20random%20shaft%20diameters%20and%20generating%20graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
diameter=np.random.normal(20,0.5,1000)
plt.hist(diameter,bins=30)
plt.show()
